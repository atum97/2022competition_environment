# %% [markdown]
# # 읍면동별 대기오염도 도출

# %%
for i in np.arange(5,9):
    df = pd.read_excel(f'./Data/종속변수/2020_대기오염/2020년 {i}월.xlsx')
    
    df = df[df['측정소명'].str[-1] != 1]    #끝글자 1을 포함하지 않는 행만 선택
    df = pd.concat([df[(df['측정소명'].str[-1] == '읍')|(df['측정소명'].str[-1] == '면')|(df['측정소명'].str[-1] == '동')],
                    df[df['측정소명'].str.contains('\)')][df[df['측정소명'].str.contains('\)')]['측정소명'].str[-2] == '읍'], 
                    df[df['측정소명'].str.contains('\)')][df[df['측정소명'].str.contains('\)')]['측정소명'].str[-2] == '면'], 
                    df[df['측정소명'].str.contains('\)')][df[df['측정소명'].str.contains('\)')]['측정소명'].str[-2] == '동']])    
    #'읍','면','동'으로 끝나고 ()안에 읍면동이 있다면 안에서 읍면동으로 끝나는 행만 선텍
    # ex. 상록구(사동)
    # str.contains() 에 \ 는 기호도 문자열로 인식하게 해줌
    
    df = df[['지역','측정소명','SO2', 'CO', 'O3', 'NO2', 'PM10','PM25']].groupby(by=['지역','측정소명']).mean().reset_index()
    df['atmosphere'] = df_5.sum(axis=1)
    # df.to_excel(f'./Data/종속변수/대기오염_{i}월.xlsx', index=False, encoding='utf-8-sig')
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_9320\221369804.py:13: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df['atmosphere'] = df_5.sum(axis=1)
# C:\Users\User\AppData\Local\Temp\ipykernel_9320\221369804.py:13: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df['atmosphere'] = df_5.sum(axis=1)
# C:\Users\User\AppData\Local\Temp\ipykernel_9320\221369804.py:13: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df['atmosphere'] = df_5.sum(axis=1)
# C:\Users\User\AppData\Local\Temp\ipykernel_9320\221369804.py:13: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df['atmosphere'] = df_5.sum(axis=1)

# %%
df_5월 = pd.read_excel('./Data/종속변수/2020_대기오염/2020년 5월.xlsx')
df_5월
# Out:
#             지역     망   측정소코드 측정소명        측정일시    SO2   CO     O3    NO2  PM10  \
# 0        서울 중구  도시대기  111121   중구  2020050101  0.003  0.3  0.038  0.008  34.0
# 1        서울 중구  도시대기  111121   중구  2020050102  0.002  0.3  0.038  0.007  37.0
# 2        서울 중구  도시대기  111121   중구  2020050103  0.003  0.4  0.036  0.009  38.0
# 3        서울 중구  도시대기  111121   중구  2020050104  0.002  0.4  0.037  0.008  43.0
# 4        서울 중구  도시대기  111121   중구  2020050105  0.003  0.4  0.038  0.008  43.0
# ...        ...   ...     ...  ...         ...    ...  ...    ...    ...   ...
# 387619  인천 옹진군  도시대기  831493   영흥  2020053120  0.004  0.3  0.069  0.006  31.0
# 387620  인천 옹진군  도시대기  831493   영흥  2020053121  0.004  0.3  0.066  0.006  32.0
# 387621  인천 옹진군  도시대기  831493   영흥  2020053122  0.004  0.3  0.060  0.007  34.0
# 387622  인천 옹진군  도시대기  831493   영흥  2020053123  0.004  0.3  0.056  0.006  29.0
# 387623  인천 옹진군  도시대기  831493   영흥  2020053124  0.004  0.3  0.054  0.006  22.0
#
#         PM25                         주소
# 0       25.0              서울 중구 덕수궁길 15
# 1       26.0              서울 중구 덕수궁길 15
# 2       29.0              서울 중구 덕수궁길 15
# 3       31.0              서울 중구 덕수궁길 15
# 4       33.0              서울 중구 덕수궁길 15
# ...      ...                        ...
# 387619  24.0  인천광역시 옹진군 영흥면 영흥로251번길 90
# 387620  24.0  인천광역시 옹진군 영흥면 영흥로251번길 90
# 387621  28.0  인천광역시 옹진군 영흥면 영흥로251번길 90
# 387622  22.0  인천광역시 옹진군 영흥면 영흥로251번길 90
# 387623  21.0  인천광역시 옹진군 영흥면 영흥로251번길 90
#
# [387624 rows x 12 columns]

# %%
df_5월 = df_5월[(df_5월['측정소명'].str[-1] == '읍')|(df_5월['측정소명'].str[-1] == '면')|(df_5월['측정소명'].str[-1] == '동')]
df_5월
# Out:
#             지역     망   측정소코드 측정소명        측정일시    SO2   CO     O3    NO2  PM10  \
# 29760   경기 수원시  도시대기  131111  신풍동  2020050101  0.001  0.6  0.050  0.006   NaN
# 29761   경기 수원시  도시대기  131111  신풍동  2020050102  0.001  0.6  0.054  0.005   NaN
# 29762   경기 수원시  도시대기  131111  신풍동  2020050103  0.001  0.6  0.056  0.004  56.0
# 29763   경기 수원시  도시대기  131111  신풍동  2020050104  0.001  0.6  0.056  0.004  46.0
# 29764   경기 수원시  도시대기  131111  신풍동  2020050105  0.001  0.6  0.053  0.004  44.0
# ...        ...   ...     ...  ...         ...    ...  ...    ...    ...   ...
# 382411  경기 부천시  도시대기  831154  오정동  2020053120  0.005  0.4  0.062  0.012  35.0
# 382412  경기 부천시  도시대기  831154  오정동  2020053121  0.005  0.4  0.062  0.012  28.0
# 382413  경기 부천시  도시대기  831154  오정동  2020053122  0.004  0.4  0.058  0.009  36.0
# 382414  경기 부천시  도시대기  831154  오정동  2020053123  0.004  0.3  0.052  0.009  30.0
# 382415  경기 부천시  도시대기  831154  오정동  2020053124  0.004  0.4  0.046  0.010   NaN
#
#         PM25                      주소
# 29760   22.0  경기 수원시 팔달구 신풍로 23번길 68
# 29761   22.0  경기 수원시 팔달구 신풍로 23번길 68
# 29762   24.0  경기 수원시 팔달구 신풍로 23번길 68
# 29763   24.0  경기 수원시 팔달구 신풍로 23번길 68
# 29764   23.0  경기 수원시 팔달구 신풍로 23번길 68
# ...      ...                     ...
# 382411  36.0          경기 부천시 성오로 172
# 382412  30.0          경기 부천시 성오로 172
# 382413  37.0          경기 부천시 성오로 172
# 382414  30.0          경기 부천시 성오로 172
# 382415  27.0          경기 부천시 성오로 172
#
# [276024 rows x 12 columns]

# %%
df_5 = df_5월[['지역','측정소명','SO2', 'CO', 'O3', 'NO2', 'PM10','PM25']].groupby(by=['지역','측정소명']).mean().reset_index()
df_5
# Out:
#          지역  측정소명       SO2        CO        O3       NO2       PM10  \
# 0    강원 강릉시   옥천동  0.002592  0.458095  0.042245  0.011095  31.867568
# 1    강원 고성군   간성읍  0.000535  0.194897  0.042759  0.002557  27.857534
# 2    강원 동해시   천곡동  0.001560  0.353731  0.031510  0.011360  26.679783
# 3    강원 삼척시   남양동  0.001754  0.308796  0.032992  0.008962  28.074425
# 4    강원 속초시   금호동  0.003148  0.416038  0.044651  0.006019  33.029650
# ..      ...   ...       ...       ...       ...       ...        ...
# 365  충북 청주시   용암동  0.003946  0.446176  0.035680  0.014089  34.945038
# 366  충북 충주시   살미면  0.003291  0.312195  0.037511  0.009615  33.374317
# 367  충북 충주시  중앙탑면  0.002388  0.253108  0.044634  0.007797  35.531800
# 368  충북 충주시   칠금동  0.003133  0.428494  0.030863  0.015841  38.057103
# 369  충북 충주시   호암동  0.002090  0.580054  0.039393  0.007254  37.587045
#
#           PM25
# 0    11.902405
# 1    11.150628
# 2    13.716196
# 3    12.358357
# 4    10.527100
# ..         ...
# 365  14.382530
# 366  15.364499
# 367  16.520270
# 368  18.032520
# 369  19.452092
#
# [370 rows x 8 columns]

# %%
df_5['atmosphere'] = df_5.sum(axis=1)
df_5
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_9320\4165982531.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df_5['atmosphere'] = df_5.sum(axis=1)
#          지역  측정소명       SO2        CO        O3       NO2       PM10  \
# 0    강원 강릉시   옥천동  0.002592  0.458095  0.042245  0.011095  31.867568
# 1    강원 고성군   간성읍  0.000535  0.194897  0.042759  0.002557  27.857534
# 2    강원 동해시   천곡동  0.001560  0.353731  0.031510  0.011360  26.679783
# 3    강원 삼척시   남양동  0.001754  0.308796  0.032992  0.008962  28.074425
# 4    강원 속초시   금호동  0.003148  0.416038  0.044651  0.006019  33.029650
# ..      ...   ...       ...       ...       ...       ...        ...
# 365  충북 청주시   용암동  0.003946  0.446176  0.035680  0.014089  34.945038
# 366  충북 충주시   살미면  0.003291  0.312195  0.037511  0.009615  33.374317
# 367  충북 충주시  중앙탑면  0.002388  0.253108  0.044634  0.007797  35.531800
# 368  충북 충주시   칠금동  0.003133  0.428494  0.030863  0.015841  38.057103
# 369  충북 충주시   호암동  0.002090  0.580054  0.039393  0.007254  37.587045
#
#           PM25  atmosphere
# 0    11.902405   44.283999
# 1    11.150628   39.248909
# 2    13.716196   40.794141
# 3    12.358357   40.785285
# 4    10.527100   44.026606
# ..         ...         ...
# 365  14.382530   49.827458
# 366  15.364499   49.101428
# 367  16.520270   52.359997
# 368  18.032520   56.567954
# 369  19.452092   57.667927
#
# [370 rows x 9 columns]

# %%
df_5.to_excel('./Data/종속변수/대기오염_5월.xlsx', index=False, encoding='utf-8-sig')

# %%
df_5월[df_5월['측정소명'].str.contains('\(')]
# Out:
# Empty DataFrame
# Columns: [지역, 망, 측정소코드, 측정소명, 측정일시, SO2, CO, O3, NO2, PM10, PM25, 주소]
# Index: []

# %%
df_6월[df_6월['측정소명'].str.contains('\)')]
# Out:
#             지역      망   측정소코드       측정소명        측정일시    SO2   CO     O3  \
# 32400   경기 수원시  도로변대기  131116  경수대로(동수원)  2020060101  0.002  0.6  0.045
# 32401   경기 수원시  도로변대기  131116  경수대로(동수원)  2020060102  0.002  0.5  0.042
# 32402   경기 수원시  도로변대기  131116  경수대로(동수원)  2020060103  0.002  0.6  0.043
# 32403   경기 수원시  도로변대기  131116  경수대로(동수원)  2020060104  0.001  0.5  0.041
# 32404   경기 수원시  도로변대기  131116  경수대로(동수원)  2020060105  0.002  0.5  0.040
# ...        ...    ...     ...        ...         ...    ...  ...    ...
# 374044  경기 부천시  도로변대기  831155   송내대로(중동)  2020063020  0.003  0.2  0.035
# 374045  경기 부천시  도로변대기  831155   송내대로(중동)  2020063021  0.003  0.2  0.027
# 374046  경기 부천시  도로변대기  831155   송내대로(중동)  2020063022  0.003  0.3  0.023
# 374047  경기 부천시  도로변대기  831155   송내대로(중동)  2020063023  0.003  0.3  0.022
# 374048  경기 부천시  도로변대기  831155   송내대로(중동)  2020063024  0.003  0.3  0.023
#
#           NO2  PM10  PM25                   주소
# 32400   0.007  27.0  13.0  경기 수원시 팔달구 인계동 1047
# 32401   0.009  18.0   6.0  경기 수원시 팔달구 인계동 1047
# 32402   0.007  22.0  12.0  경기 수원시 팔달구 인계동 1047
# 32403   0.010  18.0  13.0  경기 수원시 팔달구 인계동 1047
# 32404   0.010  16.0  10.0  경기 수원시 팔달구 인계동 1047
# ...       ...   ...   ...                  ...
# 374044  0.012   6.0   0.0      경기 부천시 송내대로 262
# 374045  0.022   6.0   1.0      경기 부천시 송내대로 262
# 374046  0.023   9.0   2.0      경기 부천시 송내대로 262
# 374047  0.020   6.0   4.0      경기 부천시 송내대로 262
# 374048  0.016   6.0   5.0      경기 부천시 송내대로 262
#
# [18000 rows x 12 columns]

# %%
df_6월['측정소명'].str[-2]
# Out:
# 0         중
# 1         중
# 2         중
# 3         중
# 4         중
#          ..
# 378748    울
# 378749    울
# 378750    울
# 378751    울
# 378752    울
# Name: 측정소명, Length: 378753, dtype: object

# %%
error_position = df_6월[df_6월['측정소명'].str.contains('\(')]['측정소명'].str.find('(')-1.

# %%
error_position = error_position.to_list()

# %%
li = df_6월[df_6월['측정소명'].str.contains('\(')]['측정소명'].to_list()
for i in range(len(li)):
    print(li[i][error_position[i]])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [326], in <cell line: 2>()
#       1 li = df_6월[df_6월['측정소명'].str.contains('\(')]['측정소명'].to_list()
#       2 for i in range(len(li)):
# ----> 3     print(li[i][error_position[i]])
#
# TypeError: string indices must be integers

# %%
df_6월[df_6월['측정소명'].str.contains('\(')]['측정소명'].unique()
# Out:
# array(['경수대로(동수원)', '호매실동(폐쇄)', '대왕판교로(백현동)', '성남대로(모란역)', '중앙대로(고잔동)',
#        '백마로(마두역)', '중부대로(구갈동)', '금암로(신장동)', '중앙동(경기)', '부곡동(울산)',
#        '여천동(울산)', '상대동(진주)', '송정1동(폐쇄)', '여천동(여수)', '중동(유해+중금속)',
#        '진상면(폐쇄)', '노원동(폐쇄)', '지품면(폐쇄)', '안계면(교외)', '상대동(대전)', '송정동(봉명동)',
#        '중앙동(강원)', '반곡동(명륜동)', '신풍동(군산)', '송내대로(중동)'], dtype=object)

# %%
pd.concat([df_6월[(df_5월['측정소명'].str[-1] == '읍')|(df_6월['측정소명'].str[-1] == '면')|(df_6월['측정소명'].str[-1] == '동')],
          df_6월[df_6월['측정소명'].str.contains('\)')][df_6월[df_6월['측정소명'].str.contains('\)')]['측정소명'].str[-2] == '읍'], 
          df_6월[df_6월['측정소명'].str.contains('\)')][df_6월[df_6월['측정소명'].str.contains('\)')]['측정소명'].str[-2] == '면'], 
          df_6월[df_6월['측정소명'].str.contains('\)')][df_6월[df_6월['측정소명'].str.contains('\)')]['측정소명'].str[-2] == '동']])
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_9320\3383718569.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   pd.concat([df_6월[(df_5월['측정소명'].str[-1] == '읍')|(df_6월['측정소명'].str[-1] == '면')|(df_6월['측정소명'].str[-1] == '동')],
#             지역      망   측정소코드      측정소명        측정일시    SO2   CO     O3    NO2  \
# 28800   경기 수원시   도시대기  131111       신풍동  2020060101  0.001  0.4  0.052  0.006
# 28801   경기 수원시   도시대기  131111       신풍동  2020060102  0.001  0.4  0.052  0.005
# 28802   경기 수원시   도시대기  131111       신풍동  2020060103  0.001  0.5  0.052  0.005
# 28803   경기 수원시   도시대기  131111       신풍동  2020060104  0.001  0.4  0.052  0.005
# 28804   경기 수원시   도시대기  131111       신풍동  2020060105  0.001  0.4  0.051  0.005
# ...        ...    ...     ...       ...         ...    ...  ...    ...    ...
# 374044  경기 부천시  도로변대기  831155  송내대로(중동)  2020063020  0.003  0.2  0.035  0.012
# 374045  경기 부천시  도로변대기  831155  송내대로(중동)  2020063021  0.003  0.2  0.027  0.022
# 374046  경기 부천시  도로변대기  831155  송내대로(중동)  2020063022  0.003  0.3  0.023  0.023
# 374047  경기 부천시  도로변대기  831155  송내대로(중동)  2020063023  0.003  0.3  0.022  0.020
# 374048  경기 부천시  도로변대기  831155  송내대로(중동)  2020063024  0.003  0.3  0.023  0.016
#
#         PM10  PM25                      주소
# 28800   18.0  16.0  경기 수원시 팔달구 신풍로 23번길 68
# 28801   15.0  15.0  경기 수원시 팔달구 신풍로 23번길 68
# 28802   20.0  14.0  경기 수원시 팔달구 신풍로 23번길 68
# 28803   22.0  16.0  경기 수원시 팔달구 신풍로 23번길 68
# 28804   17.0  15.0  경기 수원시 팔달구 신풍로 23번길 68
# ...      ...   ...                     ...
# 374044   6.0   0.0         경기 부천시 송내대로 262
# 374045   6.0   1.0         경기 부천시 송내대로 262
# 374046   9.0   2.0         경기 부천시 송내대로 262
# 374047   6.0   4.0         경기 부천시 송내대로 262
# 374048   6.0   5.0         경기 부천시 송내대로 262
#
# [225949 rows x 12 columns]
